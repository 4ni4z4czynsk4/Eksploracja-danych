# %% [markdown]
# ZADANIE1

# %%
import pandas as pd

# Dataset do zadań
temperatura = pd.DataFrame({
    'Miasto': ['Warszawa', 'Kraków', 'Gdańsk', 'Wrocław', 'Poznań', 'Łódź'],
    'Styczeń': [-2, -1, 0, -1, -2, -3],
    'Kwiecień': [9, 10, 8, 11, 10, 9],
    'Lipiec': [19, 20, 17, 21, 19, 20],
    'Październik': [9, 9, 10, 10, 9, 8]
})

print("Dataset 'temperatura' - średnie temperatury w polskich miastach:")
print(temperatura)
# Out:
# Dataset 'temperatura' - średnie temperatury w polskich miastach:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 0  Warszawa       -2         9      19            9
# 1    Kraków       -1        10      20            9
# 2    Gdańsk        0         8      17           10
# 3   Wrocław       -1        11      21           10
# 4    Poznań       -2        10      19            9
# 5      Łódź       -3         9      20            8

# %%
display(temperatura.head(3))
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 0  Warszawa       -2         9      19            9
# 1    Kraków       -1        10      20            9
# 2    Gdańsk        0         8      17           10

# %%
temperatura.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Miasto       6 non-null      object
#  1   Styczeń      6 non-null      int64
#  2   Kwiecień     6 non-null      int64
#  3   Lipiec       6 non-null      int64
#  4   Październik  6 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 372.0+ bytes

# %%
f"Nasz DataFrame ma: {temperatura.shape[0]} wierszy i {temperatura.shape[1]} kolumn"
# Out:
# 'Nasz DataFrame ma: 6 wierszy i 5 kolumn'

# %%
print(temperatura.columns.tolist())
# Out:
# ['Miasto', 'Styczeń', 'Kwiecień', 'Lipiec', 'Październik']

# %% [markdown]
# ZADANIE 2

# %%
temperatura_sort_lipiec = temperatura.sort_values(by='Lipiec', ascending=False)
display(temperatura_sort_lipiec)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 3   Wrocław       -1        11      21           10
# 1    Kraków       -1        10      20            9
# 5      Łódź       -3         9      20            8
# 0  Warszawa       -2         9      19            9
# 4    Poznań       -2        10      19            9
# 2    Gdańsk        0         8      17           10

# %%
temperatura_sort_styczen = temperatura.sort_values(by='Styczeń', ascending=True)
display(temperatura_sort_styczen)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 5      Łódź       -3         9      20            8
# 0  Warszawa       -2         9      19            9
# 4    Poznań       -2        10      19            9
# 1    Kraków       -1        10      20            9
# 3   Wrocław       -1        11      21           10
# 2    Gdańsk        0         8      17           10

# %%
temperatura_sort_lipiec_kwiecien = temperatura.sort_values(by=['Lipiec', 'Kwiecień'], ascending=[False, True])
display(temperatura_sort_lipiec_kwiecien)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 3   Wrocław       -1        11      21           10
# 5      Łódź       -3         9      20            8
# 1    Kraków       -1        10      20            9
# 0  Warszawa       -2         9      19            9
# 4    Poznań       -2        10      19            9
# 2    Gdańsk        0         8      17           10

# %% [markdown]
# ZADANIE 3

# %%
miasto_series = temperatura['Miasto']
display(miasto_series)
# Out:
# 0    Warszawa
# 1      Kraków
# 2      Gdańsk
# 3     Wrocław
# 4      Poznań
# 5        Łódź
# Name: Miasto, dtype: object

# %%
miasto_lipiec_df = temperatura[['Miasto', 'Lipiec']]
display(miasto_lipiec_df)
# Out:
#      Miasto  Lipiec
# 0  Warszawa      19
# 1    Kraków      20
# 2    Gdańsk      17
# 3   Wrocław      21
# 4    Poznań      19
# 5      Łódź      20

# %%
selected_columns = ['Miasto', 'Styczeń', 'Lipiec']
temperatura_selected = temperatura[selected_columns]
display(temperatura_selected)
# Out:
#      Miasto  Styczeń  Lipiec
# 0  Warszawa       -2      19
# 1    Kraków       -1      20
# 2    Gdańsk        0      17
# 3   Wrocław       -1      21
# 4    Poznań       -2      19
# 5      Łódź       -3      20

# %% [markdown]
# ZADANIE 4

# %%
gorace_lipiec = temperatura[temperatura['Lipiec'] > 19]
display(gorace_lipiec)
# Out:
#     Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 1   Kraków       -1        10      20            9
# 3  Wrocław       -1        11      21           10
# 5     Łódź       -3         9      20            8

# %%
cieply_styczen = temperatura[temperatura['Styczeń'] >= -1]
display(cieply_styczen)
# Out:
#     Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 1   Kraków       -1        10      20            9
# 2   Gdańsk        0         8      17           10
# 3  Wrocław       -1        11      21           10

# %%
kwiecien_10 = temperatura[temperatura['Kwiecień'] == 10]
display(kwiecien_10)
# Out:
#    Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 1  Kraków       -1        10      20            9
# 4  Poznań       -2        10      19            9

# %%
lipiec_20_lub_styczen_minus_1 = temperatura[(temperatura['Lipiec'] == 20) | (temperatura['Styczeń'] == -1)]
display(lipiec_20_lub_styczen_minus_1)
# Out:
#     Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 1   Kraków       -1        10      20            9
# 3  Wrocław       -1        11      21           10
# 5     Łódź       -3         9      20            8

# %% [markdown]
# ZADANIE 5

# %%
lipiec_powyzej_18_i_styczen_powyzej_minus_2 = temperatura[(temperatura['Lipiec'] > 18) & (temperatura['Styczeń'] >= -2)]
display(lipiec_powyzej_18_i_styczen_powyzej_minus_2)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 0  Warszawa       -2         9      19            9
# 1    Kraków       -1        10      20            9
# 3   Wrocław       -1        11      21           10
# 4    Poznań       -2        10      19            9

# %%
selected_cities = ['Warszawa', 'Kraków', 'Gdańsk']
temperatura_selected_cities = temperatura[temperatura['Miasto'].isin(selected_cities)]
display(temperatura_selected_cities)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 0  Warszawa       -2         9      19            9
# 1    Kraków       -1        10      20            9
# 2    Gdańsk        0         8      17           10

# %%
lipiec_18_do_20 = temperatura[(temperatura['Lipiec'] >= 18) & (temperatura['Lipiec'] <= 20)]
display(lipiec_18_do_20)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik
# 0  Warszawa       -2         9      19            9
# 1    Kraków       -1        10      20            9
# 4    Poznań       -2        10      19            9
# 5      Łódź       -3         9      20            8

# %% [markdown]
# ZADANIE 6

# %%
temperatura['Średnia_roczna'] = temperatura[['Styczeń', 'Kwiecień', 'Lipiec', 'Październik']].mean(axis=1)
display(temperatura)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik  Średnia_roczna
# 0  Warszawa       -2         9      19            9            8.75
# 1    Kraków       -1        10      20            9            9.50
# 2    Gdańsk        0         8      17           10            8.75
# 3   Wrocław       -1        11      21           10           10.25
# 4    Poznań       -2        10      19            9            9.00
# 5      Łódź       -3         9      20            8            8.50

# %%
temperatura['Amplituda'] = temperatura['Lipiec'] - temperatura['Styczeń']
display(temperatura)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik  Średnia_roczna  Amplituda
# 0  Warszawa       -2         9      19            9            8.75         21
# 1    Kraków       -1        10      20            9            9.50         21
# 2    Gdańsk        0         8      17           10            8.75         17
# 3   Wrocław       -1        11      21           10           10.25         22
# 4    Poznań       -2        10      19            9            9.00         21
# 5      Łódź       -3         9      20            8            8.50         23

# %%
temperatura['Ciepłe_miasto'] = temperatura['Średnia_roczna'] > 11
display(temperatura)
# Out:
#      Miasto  Styczeń  Kwiecień  Lipiec  Październik  Średnia_roczna  \
# 0  Warszawa       -2         9      19            9            8.75
# 1    Kraków       -1        10      20            9            9.50
# 2    Gdańsk        0         8      17           10            8.75
# 3   Wrocław       -1        11      21           10           10.25
# 4    Poznań       -2        10      19            9            9.00
# 5      Łódź       -3         9      20            8            8.50
#
#    Amplituda  Ciepłe_miasto
# 0         21          False
# 1         21          False
# 2         17          False
# 3         22          False
# 4         21          False
# 5         23          False

# %% [markdown]
# ## **Zadanie: zaawansowane**
#
#
# ```
# # Nowy dataset dla zaawansowanego zadania
# wyniki_egzaminy = pd.DataFrame({
#     'Student': ['Anna', 'Bartek', 'Celina', 'Damian', 'Ewa', 'Filip', 'Gabriela', 'Hubert'],
#     'Matematyka': [85, 92, 78, 88, 95, 72, 89, 81],
#     'Fizyka': [78, 88, 82, 75, 91, 68, 85, 79],
#     'Informatyka': [92, 85, 88, 90, 89, 95, 82, 87],
#     'Kierunek': ['Informatyka', 'Fizyka', 'Matematyka', 'Informatyka',
#                  'Matematyka', 'Informatyka', 'Fizyka', 'Matematyka']
# })
# ```
#
#
#
#
#
# a) Dodaj kolumnę 'Średnia' z wyników z trzech przedmiotów
#
# b) Dodaj kolumnę 'Status' - 'Zaliczony' jeśli średnia >= 85, 'Niezaliczony' w przeciwnym razie
#
# c) Dla każdego kierunku znajdź studenta z najwyższą średnią:
#    - Przefiltruj po kierunku
#    - Posortuj według średniej malejąco
#    - Weź pierwszy wiersz
#    - Wykonaj dla każdego z 3 kierunków
#
# d) Znajdź wszystkich studentów informatyki, którzy mają średnią >= 85
#    i wynik z informatyki >= 90, posortowanych według średniej malejąco

# %%
import pandas as pd
# Nowy dataset dla zaawansowanego zadania
wyniki_egzaminy = pd.DataFrame({
    'Student': ['Anna', 'Bartek', 'Celina', 'Damian', 'Ewa', 'Filip', 'Gabriela', 'Hubert'],
    'Matematyka': [85, 92, 78, 88, 95, 72, 89, 81],
    'Fizyka': [78, 88, 82, 75, 91, 68, 85, 79],
    'Informatyka': [92, 85, 88, 90, 89, 95, 82, 87],
    'Kierunek': ['Informatyka', 'Fizyka', 'Matematyka', 'Informatyka',
                 'Matematyka', 'Informatyka', 'Fizyka', 'Matematyka']
})

# %%
wyniki_egzaminy['Średnia'] = wyniki_egzaminy[['Matematyka', 'Fizyka', 'Informatyka']].mean(axis=1)
display(wyniki_egzaminy)
# Out:
#     Student  Matematyka  Fizyka  Informatyka     Kierunek    Średnia
# 0      Anna          85      78           92  Informatyka  85.000000
# 1    Bartek          92      88           85       Fizyka  88.333333
# 2    Celina          78      82           88   Matematyka  82.666667
# 3    Damian          88      75           90  Informatyka  84.333333
# 4       Ewa          95      91           89   Matematyka  91.666667
# 5     Filip          72      68           95  Informatyka  78.333333
# 6  Gabriela          89      85           82       Fizyka  85.333333
# 7    Hubert          81      79           87   Matematyka  82.333333

# %%
wyniki_egzaminy['Status'] = wyniki_egzaminy['Średnia'].apply(lambda x: 'Zaliczony' if x >= 85 else 'Niezaliczony')
display(wyniki_egzaminy)
# Out:
#     Student  Matematyka  Fizyka  Informatyka     Kierunek    Średnia  \
# 0      Anna          85      78           92  Informatyka  85.000000
# 1    Bartek          92      88           85       Fizyka  88.333333
# 2    Celina          78      82           88   Matematyka  82.666667
# 3    Damian          88      75           90  Informatyka  84.333333
# 4       Ewa          95      91           89   Matematyka  91.666667
# 5     Filip          72      68           95  Informatyka  78.333333
# 6  Gabriela          89      85           82       Fizyka  85.333333
# 7    Hubert          81      79           87   Matematyka  82.333333
#
#          Status
# 0     Zaliczony
# 1     Zaliczony
# 2  Niezaliczony
# 3  Niezaliczony
# 4     Zaliczony
# 5  Niezaliczony
# 6     Zaliczony
# 7  Niezaliczony

# %%
informatyka_df = wyniki_egzaminy[wyniki_egzaminy['Kierunek'] == 'Informatyka']
najlepszy_informatyka = informatyka_df.sort_values(by='Średnia', ascending=False).iloc[0]
display(najlepszy_informatyka)
# Out:
# Student               Anna
# Matematyka              85
# Fizyka                  78
# Informatyka             92
# Kierunek       Informatyka
# Średnia               85.0
# Status           Zaliczony
# Name: 0, dtype: object

# %%
fizyka_df = wyniki_egzaminy[wyniki_egzaminy['Kierunek'] == 'Fizyka']
najlepszy_fizyka = fizyka_df.sort_values(by='Średnia', ascending=False).iloc[0]
display(najlepszy_fizyka)
# Out:
# Student           Bartek
# Matematyka            92
# Fizyka                88
# Informatyka           85
# Kierunek          Fizyka
# Średnia        88.333333
# Status         Zaliczony
# Name: 1, dtype: object

# %%
matematyka_df = wyniki_egzaminy[wyniki_egzaminy['Kierunek'] == 'Matematyka']
najlepszy_matematyka = matematyka_df.sort_values(by='Średnia', ascending=False).iloc[0]
display(najlepszy_matematyka)
# Out:
# Student               Ewa
# Matematyka             95
# Fizyka                 91
# Informatyka            89
# Kierunek       Matematyka
# Średnia         91.666667
# Status          Zaliczony
# Name: 4, dtype: object
